# %%
import tkinter as tk
from tkinter import Canvas, Button
from PIL import Image, ImageDraw, ImageOps
import os
import random

# %% [markdown]
# # Drawing data

# %% [markdown]
# Circles

# %%
class DrawingApp:
    def __init__(self, master, width=240, height=240):
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_save.pack()
        
        self.new_canvas()  # Create a new drawing canvas
        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "Shapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/circle{self.image_count}.png"
        self.image.save(filename)
        print(f"Image saved as {filename}")
        self.image_count += 1
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("Shapes") if f.startswith("circle") and f.endswith(".png")]
        if image_files:
            self.image_count = max(int(f.split("circle")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.image_count = 1

def main():
    root = tk.Tk()
    root.title("CIRCLES")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Image saved as Shapes/circle1.png
# Image saved as Shapes/circle2.png
# Image saved as Shapes/circle3.png
# Image saved as Shapes/circle4.png
# Image saved as Shapes/circle5.png
# Image saved as Shapes/circle6.png
# Image saved as Shapes/circle7.png
# Image saved as Shapes/circle8.png
# Image saved as Shapes/circle9.png
# Image saved as Shapes/circle10.png
# Image saved as Shapes/circle11.png
# Image saved as Shapes/circle12.png
# Image saved as Shapes/circle13.png
# Image saved as Shapes/circle14.png
# Image saved as Shapes/circle15.png
# Image saved as Shapes/circle16.png
# Image saved as Shapes/circle17.png
# Image saved as Shapes/circle18.png
# Image saved as Shapes/circle19.png
# Image saved as Shapes/circle20.png

# %% [markdown]
# Squares

# %%
class DrawingApp:
    def __init__(self, master, width=240, height=240):
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_save.pack()
        
        self.new_canvas()  # Create a new drawing canvas
        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "Shapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/square{self.image_count}.png"
        self.image.save(filename)
        print(f"Image saved as {filename}")
        self.image_count += 1
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("Shapes") if f.startswith("square") and f.endswith(".png")]
        if image_files:
            self.image_count = max(int(f.split("square")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.image_count = 1

def main():
    root = tk.Tk()
    root.title("SQUARES")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Image saved as Shapes/square2.png
# Image saved as Shapes/square3.png
# Image saved as Shapes/square4.png
# Image saved as Shapes/square5.png
# Image saved as Shapes/square6.png
# Image saved as Shapes/square7.png
# Image saved as Shapes/square8.png
# Image saved as Shapes/square9.png
# Image saved as Shapes/square10.png
# Image saved as Shapes/square11.png
# Image saved as Shapes/square12.png
# Image saved as Shapes/square13.png
# Image saved as Shapes/square14.png
# Image saved as Shapes/square15.png
# Image saved as Shapes/square16.png
# Image saved as Shapes/square17.png
# Image saved as Shapes/square18.png
# Image saved as Shapes/square19.png
# Image saved as Shapes/square20.png

# %% [markdown]
# Triangles

# %%
class DrawingApp:
    def __init__(self, master, width=240, height=240):
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_save.pack()
        
        self.new_canvas()  # Create a new drawing canvas
        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "Shapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/triangle{self.image_count}.png"
        self.image.save(filename)
        print(f"Image saved as {filename}")
        self.image_count += 1
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("Shapes") if f.startswith("triangle") and f.endswith(".png")]
        if image_files:
            self.image_count = max(int(f.split("triangle")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.image_count = 1

def main():
    root = tk.Tk()
    root.title("TRIANGLES")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Image saved as Shapes/triangle1.png
# Image saved as Shapes/triangle2.png
# Image saved as Shapes/triangle3.png
# Image saved as Shapes/triangle4.png
# Image saved as Shapes/triangle5.png
# Image saved as Shapes/triangle6.png
# Image saved as Shapes/triangle7.png
# Image saved as Shapes/triangle8.png
# Image saved as Shapes/triangle9.png
# Image saved as Shapes/triangle10.png
# Image saved as Shapes/triangle11.png
# Image saved as Shapes/triangle12.png
# Image saved as Shapes/triangle13.png
# Image saved as Shapes/triangle14.png
# Image saved as Shapes/triangle15.png
# Image saved as Shapes/triangle16.png
# Image saved as Shapes/triangle17.png
# Image saved as Shapes/triangle18.png
# Image saved as Shapes/triangle19.png
# Image saved as Shapes/triangle20.png
# Image saved as Shapes/triangle21.png

# %% [markdown]
# Pentagons

# %%
class DrawingApp:
    def __init__(self, master, width=240, height=240):
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_save.pack()
        
        self.new_canvas()  # Create a new drawing canvas
        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "Shapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/pentagon{self.image_count}.png"
        self.image.save(filename)
        print(f"Image saved as {filename}")
        self.image_count += 1
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("Shapes") if f.startswith("pentagon") and f.endswith(".png")]
        if image_files:
            self.image_count = max(int(f.split("pentagon")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.image_count = 1

def main():
    root = tk.Tk()
    root.title("PENTAGONS")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Image saved as Shapes/pentagon16.png
# Image saved as Shapes/pentagon17.png
# Image saved as Shapes/pentagon18.png
# Image saved as Shapes/pentagon19.png
# Image saved as Shapes/pentagon20.png

# %% [markdown]
# Hexagons

# %%
class DrawingApp:
    def __init__(self, master, width=240, height=240):
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_save.pack()
        
        self.new_canvas()  # Create a new drawing canvas
        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "Shapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/hexagon{self.image_count}.png"
        self.image.save(filename)
        print(f"Image saved as {filename}")
        self.image_count += 1
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("Shapes") if f.startswith("hexagon") and f.endswith(".png")]
        if image_files:
            self.image_count = max(int(f.split("hexagon")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.image_count = 1

def main():
    root = tk.Tk()
    root.title("HEXAGONS")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Image saved as Shapes/hexagon21.png

# %% [markdown]
# # App for all shapes

# %%
labels_map = {
    "circle": 0,
    "square": 1,
    "triangle": 2,
    "pentagon": 3,
    "hexagon": 4,
}
reverse_labels_map = {value: key for key, value in labels_map.items()}

class DrawingApp:
    def __init__(self, master, width=240, height=240):

        self.mode = 0
        self.label = "circle"
        self.master = master
        self.width = width
        self.height = height
        
        self.find_highest_image_count()  # Find the highest numbered image file
        self.canvas = tk.Canvas(master, width=self.width, height=self.height, bg="white")
        self.canvas.pack()
        
        self.canvas.bind("<B1-Motion>", self.draw)
        
        self.button_save = tk.Button(master, text="Save", command=self.save_image)
        self.button_circle_mode = tk.Button(master, text="Circle", command=lambda: self.change_mode(mode=0))
        self.button_square_mode = tk.Button(master, text="Square", command=lambda: self.change_mode(mode=1))
        self.button_triangle_mode = tk.Button(master, text="Triangle", command=lambda: self.change_mode(mode=2))
        self.button_pentagon_mode = tk.Button(master, text="Pentagon", command=lambda: self.change_mode(mode=3))
        self.button_hexagon_mode = tk.Button(master, text="Hexagon", command=lambda: self.change_mode(mode=4))
        self.button_circle_mode.pack()
        self.button_square_mode.pack()
        self.button_triangle_mode.pack()
        self.button_pentagon_mode.pack()
        self.button_hexagon_mode.pack()
        self.button_save.pack()

        
        self.new_canvas()  # Create a new drawing canvas

    def change_mode(self, mode):
        self.mode = mode
        label = reverse_labels_map.get(self.mode)

        if label is not None:
            self.label = label
            print(label + " mode")

        else:
            print("Value not found in labels map.")
            

        
    def draw(self, event):
        x, y = event.x, event.y
        r = 3
        self.canvas.create_oval(x-r, y-r, x+r, y+r, fill="black")
        self.draw.ellipse([x-r, y-r, x+r, y+r], fill="black")
        
    def save_image(self):
        directory = "CollectedShapes"
        if not os.path.exists(directory):
            os.makedirs(directory)
        if self.mode == 0:
            filename = f"{directory}/{self.label}{self.circle_count}.png"
            self.image.save(filename)
            print(f"Image saved as {filename}")
            self.circle_count += 1
        elif self.mode == 1:
            filename = f"{directory}/{self.label}{self.square_count}.png"
            self.image.save(filename)
            print(f"Image saved as {filename}")
            self.square_count += 1
        elif self.mode == 2:
            filename = f"{directory}/{self.label}{self.triangle_count}.png"
            self.image.save(filename)
            print(f"Image saved as {filename}")
            self.triangle_count += 1  
        elif self.mode == 3:
            filename = f"{directory}/{self.label}{self.pentagon_count}.png"
            self.image.save(filename)
            print(f"Image saved as {filename}")
            self.pentagon_count += 1  
        elif self.mode == 4:
            filename = f"{directory}/{self.label}{self.hexagon_count}.png"
            self.image.save(filename)
            print(f"Image saved as {filename}")
            self.hexagon_count += 1    
        self.new_canvas()  # Create a new drawing canvas
        
    def new_canvas(self):
        self.canvas.delete("all")  # Clear the canvas
        self.image = Image.new("RGB", (self.width, self.height), "white")
        self.draw = ImageDraw.Draw(self.image)
        
    def find_highest_image_count(self):
        image_files = [f for f in os.listdir("CollectedShapes") if f.startswith("circle") and f.endswith(".png")]
        if image_files:
            self.circle_count = max(int(f.split("circle")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.circle_count = 1

        image_files = [f for f in os.listdir("CollectedShapes") if f.startswith("square") and f.endswith(".png")]
        if image_files:
            self.square_count = max(int(f.split("square")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.square_count = 1

        image_files = [f for f in os.listdir("CollectedShapes") if f.startswith("triangle") and f.endswith(".png")]
        if image_files:
            self.triangle_count = max(int(f.split("triangle")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.triangle_count = 1

        image_files = [f for f in os.listdir("CollectedShapes") if f.startswith("pentagon") and f.endswith(".png")]
        if image_files:
            self.pentagon_count = max(int(f.split("pentagon")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.pentagon_count = 1

        image_files = [f for f in os.listdir("CollectedShapes") if f.startswith("hexagon") and f.endswith(".png")]
        if image_files:
            self.hexagon_count = max(int(f.split("hexagon")[1].split(".png")[0]) for f in image_files) + 1
        else:
            self.hexagon_count = 1


def main():
    root = tk.Tk()
    root.title("Draw Shapes")
    app = DrawingApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()

# %% [markdown]
# Rotations and shifts

# %%
def random_rotate_and_shift(input_path, output_path, max_rotation=20, max_shift=20):
    """
    Randomly rotate an image by a random angle within a specified range
    and add a random shift within a specified range.
    
    Args:
        input_path (str): Path to the input image file.
        output_path (str): Path to save the transformed image.
        max_rotation (int): Maximum angle for rotation in degrees.
        max_shift (int): Maximum shift in pixels.
    
    Returns:
        None
    """
    # Open the image file
    image = Image.open(input_path).convert("L")
    
    # Create an output image with the same dimensions as the input image
    output_image = Image.new("L", image.size)
    
    # Generate random rotation angle
    rotation_angle = random.uniform(-max_rotation, max_rotation)
    
    # Rotate the image by the random angle
    rotated_image = image.rotate(rotation_angle, resample=Image.BICUBIC, expand=True)
    
    # Generate random shift
    shift_x = random.randint(-max_shift, max_shift)
    shift_y = random.randint(-max_shift, max_shift)
    
    # Paste the rotated image onto the output image with the random shift
    output_image.paste(rotated_image, (shift_x, shift_y))
    
    # Save the transformed image
    output_image.save(output_path)

# Example usage
input_path = "Shapes/circle1.png"
output_path = "Data/circle1.png"
random_rotate_and_shift(input_path, output_path)

# %%
def random_reflection(input_path, output_path):
    """
    Randomly perform horizontal or vertical reflection on the image.
    
    Args:
        input_path (str): Path to the input image file.
        output_path (str): Path to save the transformed image.
    
    Returns:
        None
    """
    # Open the image file
    image = Image.open(input_path).convert("L")
    
    # Create an output image with the same dimensions as the input image
    output_image = Image.new("L", image.size)
    
    # Randomly select horizontal or vertical reflection
    reflection_type = random.choice(["horizontal", "vertical"])
    
    # Apply reflection
    if reflection_type == "horizontal":
        output_image = ImageOps.mirror(image)
    else:
        output_image = ImageOps.flip(image)
    
    # Save the transformed image
    output_image.save(output_path)

# Example usage
input_path = "Shapes/circle1.png"
output_path = "Data/circle1_reflected.png"
random_reflection(input_path, output_path)

# %%
def apply_random_transforms_to_folder(input_folder, output_folder, max_rotation=20, max_shift=20, num_transformations=20):
    """
    Apply random rotation and shift transformations multiple times to all images in a folder
    and save the transformed images with the same name appended with _1, _2, etc.
    
    Args:
        input_folder (str): Path to the input folder containing images.
        output_folder (str): Path to the output folder to save transformed images.
        max_rotation (int): Maximum angle for rotation in degrees.
        max_shift (int): Maximum shift in pixels.
        num_transformations (int): Number of times to apply random transformations.
    
    Returns:
        None
    """
    # Ensure output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Iterate over each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".png") or filename.endswith(".jpg"):
            input_path = os.path.join(input_folder, filename)
            
            # Generate and save multiple transformed images
            for i in range(num_transformations):
                output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_{i+1}.png")
                random_rotate_and_shift(input_path, output_path, max_rotation, max_shift)

# %% [markdown]
# # Training Data

# %%
input_folder = "Shapes/"
output_folder = "Data/"
apply_random_transforms_to_folder(input_folder, output_folder)

# %% [markdown]
# # Testing Data

# %%
input_folder = "Shapes/"
output_folder = "Test/"
apply_random_transforms_to_folder(input_folder, output_folder, num_transformations=5)
